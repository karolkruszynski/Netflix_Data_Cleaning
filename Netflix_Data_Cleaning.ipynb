# %% [markdown]
# <a href="https://colab.research.google.com/github/karolkruszynski/Netflix_Data_Cleaning/blob/main/Netflix_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Set Load

# %%
df = pd.read_csv('/content/netflix_titles.csv')

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.duplicated().value_counts()
# Out:
# False    8807
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Manipulation with Date Time Data

# %% [markdown]
# There are no duplicate values

# %% [markdown]
# date_added is object type and needs to be converted to datetime.
#
# Format: mm/dd/yyyy

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %% [markdown]
# # Separation of Listed Columns

# %% [markdown]
# Listed columns should be separated, we must split the columns into multiple columns

# %% [markdown]
# drop column i we don't need
# show_id,
# listed_in,
# director

# %%
df[['Listed_in_1', 'Listed_in_2', 'Listed_in_3']] = df['listed_in'].str.split(', ', expand=True)

# %%
df[['Director_1', 'Director_Others']] = df['director'].str.split(', ', 1 ,expand=True)
# Out:
# <ipython-input-68-546f2f8a1a4c>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Director_1', 'Director_Others']] = df['director'].str.split(', ', 1 ,expand=True)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description             Listed_in_1  \
# 0  As her father nears the end of his life, filmm...           Documentaries
# 1  After crossing paths at a party, a Cape Town t...  International TV Shows
# 2  To protect his family from a powerful drug lor...          Crime TV Shows
# 3  Feuds, flirtations and toilet talk go down amo...              Docuseries
# 4  In a city of coaching centers known to train I...  International TV Shows
#
#               Listed_in_2            Listed_in_3       Director_1  \
# 0                    None                   None  Kirsten Johnson
# 1               TV Dramas           TV Mysteries              NaN
# 2  International TV Shows  TV Action & Adventure  Julien Leclercq
# 3              Reality TV                   None              NaN
# 4       Romantic TV Shows            TV Comedies              NaN
#
#   Director_Others
# 0            None
# 1             NaN
# 2            None
# 3             NaN
# 4             NaN

# %% [markdown]
# # Manipulation with Duration Column

# %%
df['duration'].value_counts()
# Out:
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
#              ...
# 16 min          1
# 186 min         1
# 193 min         1
# 189 min         1
# 191 min         1
# Name: duration, Length: 220, dtype: int64

# %% [markdown]
# duration is object type and needs to be converted
#
# sometimes duration has values in minutes or hours or seasons

# %%
columns_to_drop = ['show_id', 'director', 'listed_in']
df = df.drop(columns=columns_to_drop)

# %% [markdown]
# I assume that 1 season is equal to 30 episodes and 1 episode is 24 minutes

# %%
df['duration_numeric'] = df['duration'].str.extract('(\d+)').astype(float)

# %% [markdown]
# Convert durations to minutes based on their units

# %%
df.loc[df['duration'].str.contains('Season').fillna(False),'duration_numeric'] *= 30 * 24 * 60

# %%
df.loc[df['duration'].str.contains('min').fillna(False),'duration_numeric'] # no conversion needed for minutes
# Out:
# 0        90.0
# 6        91.0
# 7       125.0
# 9       104.0
# 12      127.0
#         ...
# 8801     96.0
# 8802    158.0
# 8804     88.0
# 8805     88.0
# 8806    111.0
# Name: duration_numeric, Length: 6128, dtype: float64

# %%
df['duration_numeric'].isna().sum()
# Out:
# 3

# %% [markdown]
# drop old duration column

# %%
df = df.drop(columns=['duration'])

# %% [markdown]
# filtre rows with missing values

# %%
rows_to_drop = df.loc[df['duration_numeric'].isna()]

# %% [markdown]
# drop rows with missing values

# %%
df.drop(rows_to_drop.index, inplace=True)

# %%
df['duration_numeric'].isna().sum()
# Out:
# 0

# %%
df.loc[df['title'].isin(["Peaky Blinders"])]
# Out:
#          type           title  \
# 3452  TV Show  Peaky Blinders
#
#                                                    cast         country  \
# 3452  Cillian Murphy, Sam Neill, Helen McCrory, Paul...  United Kingdom
#
#      date_added  release_year rating  \
# 3452 2019-10-04          2019  TV-MA
#
#                                             description       Listed_in_1  \
# 3452  A notorious gang in 1919 Birmingham, England, ...  British TV Shows
#
#          Listed_in_2             Listed_in_3 Director_1 Director_Others  \
# 3452  Crime TV Shows  International TV Shows        NaN             NaN
#
#       duration_numeric
# 3452          216000.0

# %%
df.loc[df['duration_numeric'].between(0, 30)]
# Out:
#        type                                              title  \
# 45    Movie                             My Heroes Were Cowboys
# 71    Movie                        A StoryBots Space Adventure
# 694   Movie                                              Aziza
# 695   Movie                                     Besieged Bread
# 811   Movie                  Super Monsters: Once Upon a Rhyme
# ...     ...                                                ...
# 7787  Movie          Power Rangers: Megaforce: Raising Spirits
# 7788  Movie  Power Rangers: Megaforce: The Robo Knight Befo...
# 7848  Movie                                            Refugee
# 7891  Movie                                  Room on the Broom
# 8205  Movie                               The Battle of Midway
#
#                                                    cast  \
# 45                                                  NaN
# 71    Evan Spiridellis, Erin Fitzgerald, Jeff Gill, ...
# 694                  Caress Bashar, Abdel Moneim Amayri
# 695            Lama Hakeim, Gabriel Malki, Ehab Shaaban
# 811   Elyse Maloway, Vincent Tong, Andrea Libman, Al...
# ...                                                 ...
# 7787  Andrew M. Gray, John Mark Loudermilk, Ciara Ha...
# 7788  Andrew M. Gray, Ciara Hanna, John Mark Louderm...
# 7848  Cate Blanchett, Lynsey Addario, Omar Victor Di...
# 7891  Simon Pegg, Gillian Anderson, Rob Brydon, Mart...
# 8205                          Henry Fonda, Jane Darwell
#
#                       country date_added  release_year rating  \
# 45                        NaN 2021-09-16          2021     PG
# 71                        NaN 2021-09-14          2021   TV-Y
# 694            Lebanon, Syria 2021-06-17          2019  TV-PG
# 695                       NaN 2021-06-17          2015  TV-14
# 811                       NaN 2021-06-02          2021   TV-Y
# ...                       ...        ...           ...    ...
# 7787            United States 2016-01-01          2013  TV-Y7
# 7788            United States 2016-01-01          2013  TV-Y7
# 7848                      NaN 2017-03-10          2016  TV-PG
# 7891  United Kingdom, Germany 2019-07-01          2012  TV-Y7
# 8205            United States 2017-03-31          1942  TV-14
#
#                                             description  \
# 45    Robin Wiltshire's painful childhood was rescue...
# 71    Join the StoryBots and the space travelers of ...
# 694   This short film follows a newly displaced Syri...
# 695   In battle-ridden Syria, a woman trying to smug...
# 811   From Goldilocks to Hansel and Gretel, the Supe...
# ...                                                 ...
# 7787  On Halloween, the scariest night of the year, ...
# 7788  Robo Knight learns the meaning of Christmas fr...
# 7848  Five acclaimed photographers travel the world ...
# 7891  A gentle witch with a ginger braid offers ride...
# 8205  Director John Ford captures combat footage of ...
#
#                    Listed_in_1           Listed_in_2         Listed_in_3  \
# 45               Documentaries                  None                None
# 71    Children & Family Movies                  None                None
# 694                   Comedies                Dramas  Independent Movies
# 695                     Dramas  International Movies                None
# 811   Children & Family Movies                  None                None
# ...                        ...                   ...                 ...
# 7787  Children & Family Movies                  None                None
# 7788  Children & Family Movies                  None                None
# 7848             Documentaries                  None                None
# 7891  Children & Family Movies    Independent Movies                None
# 8205            Classic Movies         Documentaries                None
#
#              Director_1 Director_Others  duration_numeric
# 45          Tyler Greco            None              23.0
# 71      David A. Vargas            None              13.0
# 694      Soudade Kaadan            None              13.0
# 695      Soudade Kaadan            None              12.0
# 811          Steve Ball            None              25.0
# ...                 ...             ...               ...
# 7787                NaN             NaN              24.0
# 7788         James Barr            None              24.0
# 7848  Clementine Malpas    Leslie Knott              24.0
# 7891           Max Lang   Jani Lachauer              26.0
# 8205          John Ford            None              18.0
#
# [130 rows x 14 columns]
